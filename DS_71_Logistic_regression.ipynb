# %% [markdown]
# <a href="https://colab.research.google.com/github/santhosh47/Data_Science_and_ML_Tutorial/blob/main/DS_71_Logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Course_Notes_Logistic_Regression-3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Course_Notes_Logistic_Regression-4.jpg](data:image/jpeg;base64,...)
