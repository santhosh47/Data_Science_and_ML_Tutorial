# %% [markdown]
# ![Course_Notes_Cluster_Analysis-2.jpg](attachment:Course_Notes_Cluster_Analysis-2.jpg)

# %% [markdown]
# ## A Cluster Analysis Example
#
# ![Image-2.jpg](attachment:Image-2.jpg)

# %% [markdown]
# ![Image-02.jpg](attachment:Image-02.jpg)

# %% [markdown]
# ![Image-3.jpg](attachment:Image-3.jpg)

# %% [markdown]
# ![Image-04.jpg](attachment:Image-04.jpg)

# %% [markdown]
# ![IMage-05.jpg](attachment:IMage-05.jpg)

# %% [markdown]
# ![Course_Notes_Cluster_Analysis-3.jpg](attachment:Course_Notes_Cluster_Analysis-3.jpg)

# %% [markdown]
# ![image.png](attachment:image.png)
