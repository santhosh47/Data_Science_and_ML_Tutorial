# %% [markdown]
# <a href="https://colab.research.google.com/github/santhosh47/Data_Science_and_ML_Tutorial/blob/main/DS_15_Probability_Basics_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Complements**
#
# Simply put, a compliment of an event is everything the event is not.
#
# ![p7rgpsdsgp-complement.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Sum of Porbabilties of  all the events is always one
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Course+Notes+-+Basic+Probability-6.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##**Probability Combinatronics**
#
# combinatorics deals with combinations
# of objects from a specific finite set.
#
# We will explore the three integral parts of combinatorics,
# permutations, variations, and combinations.
# Then we will use each of these parts
# to determine the number of favorable outcomes
# or the number of all elements in a sample space.

# %% [markdown]
# # **Permutation:**
#
# Permutations represents the number
# of different possible ways we can arrange a set of elements.
#
# These elements can be digits, letters, objects,
# or even people.
#
# ![Course+Notes+-+Combinatorics-1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Course+Notes+-+Combinatorics-2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Course+Notes+-+Combinatorics-3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Combinations**
#
# Combinations represent the number of different ways
# we can pick certain elements of a set
#
# **Example:**
#
# Imagine you were trying to pick three people
# to represent your company
# on a very important technology related conference.
#
# There are 10 people working in the office,
# so how many different combinations are there?
# If you calculated this as a **variation
# your answer would be 720**, but you would be counting every group of three people several times over.
#
# ###**Variations don't take into account double counting elements**
#
# That is where combinations step in,
#
# **We can say that all the different permutations of a single combination are different variations.**

# %% [markdown]
# ![Course+Notes+-+Combinatorics-4.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Course+Notes+-+Combinatorics-5.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Course+Notes+-+Combinatorics-6.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Symmetry+Explained-1.jpg](data:image/jpeg;base64,...)
