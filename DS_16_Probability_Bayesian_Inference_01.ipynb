# %% [markdown]
# <a href="https://colab.research.google.com/github/santhosh47/Data_Science_and_ML_Tutorial/blob/main/DS_16_Probability_Bayesian_Inference_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Sets and Events**
# Every event has a set of outcomes that satisfy it.
#
# These are the favorable outcomes.
#
# For example, the event could be being even,
# and the set of values would consist of two, four, six,
# and all other even numbers.
#
# However, values of a set don't always have to be numerical.
# For instance, an event can be being a member
# of the European Union.
# Values like France or Germany would be a part of this set,
# and values like USA or Japan would not.
#
# Convention dictates that we use uppercase letters
# to denote these sets and lowercase letters
# to express individual elements.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Non-Empty Sets**
# Non-empty sets can be finite or infinite,
# depending on the number of elements they have.
#
# When working with them, we often want to express
# if an element is part of a set. The symbol we use to denote that is the E symbol.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Course+Notes+-+Bayesian+Inference-01.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Course+Notes+-+Bayesian+Inference-02.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Course+Notes+-+Bayesian+Inference-03.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Course+Notes+-+Bayesian+Inference-04.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Course+Notes+-+Bayesian+Inference-05.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Course+Notes+-+Bayesian+Inference-06.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Course+Notes+-+Bayesian+Inference-07.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Course+Notes+-+Bayesian+Inference-08.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Course+Notes+-+Bayesian+Inference-09.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Course+Notes+-+Bayesian+Inference-10.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Course+Notes+-+Bayesian+Inference-11.jpg](data:image/jpeg;base64,...)
