# %% [markdown]
# ![Course_Notes_Cluster_Analysis-4.jpg](attachment:Course_Notes_Cluster_Analysis-4.jpg)

# %% [markdown]
# ![Course_Notes_Cluster_Analysis-5.jpg](attachment:Course_Notes_Cluster_Analysis-5.jpg)
